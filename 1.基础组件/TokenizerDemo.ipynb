# %%
from tokenize import tokenize

from transformers import AutoTokenizer

# %%
sen = "弱小的我也有梦想！"

# %%
tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-chinese")

# %%
# 编码
ids = tokenizer.encode_plus(sen, add_special_tokens=False)
# 等价 ids = tokenizer.encode(sen,add_special_tokens=False)
ids
# Out:
# {'input_ids': [2483, 2207, 4638, 2769, 738, 3300, 3457, 2682, 8013], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
# 解码
str_sen = tokenizer.decode(ids)
str_sen
# Out:
# '弱 小 的 我 也 有 梦 想 ！'
